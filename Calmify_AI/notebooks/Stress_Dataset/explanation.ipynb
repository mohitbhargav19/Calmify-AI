# %% [markdown]
# # <b><u><i>Stress_Dataset </u>----</b></i>

# %% [markdown]
# <B><I>ALL THE FEATURES OF <U>Stress_Dataset</U> THIS DATASET ARE AS FOLLOWS --></B></I>

# %% [markdown]
# | #  | Column Name                                                              | Short Meaning                                        | Feature Type                  | Importance for Stress Prediction                                                                            |
# | -- | ------------------------------------------------------------------------ | ---------------------------------------------------- | ----------------------------- | ----------------------------------------------------------------------------------------------------------- |
# | 1  | **Gender**                                                               | Student ka gender                                    | Demographic                   | Stress patterns gender ke hisaab se differ kar sakte hain; useful but usually not strongest predictor       |
# | 2  | **Age**                                                                  | Student ki age                                       | Demographic                   | Different age groups me academic pressure aur coping style alag ho sakta hai                                |
# | 3  | **Have you recently experienced stress in your life?**                   | Overall recent stress experience                     | Core stress indicator         | **Very important** — direct signal hai ki person recent stress face kar raha hai                            |
# | 4  | **Have you noticed a rapid heartbeat or palpitations?**                  | Stress ke physical symptoms jaise fast heartbeat     | Physical symptom              | Anxiety/stress ke physical manifestations ko capture karta hai                                              |
# | 5  | **Have you been dealing with anxiety or tension recently?**              | Recent anxiety/tension level                         | Emotional symptom             | **Highly important** — stress ke strongest emotional indicators me se ek                                    |
# | 6  | **Do you face any sleep problems or difficulties falling asleep?**       | Sleep issues / insomnia tendency                     | Lifestyle + symptom           | Stress aur poor sleep strongly linked hote hain                                                             |
# | 7  | **Have you been dealing with anxiety or tension recently?.1**            | Likely duplicate / repeated anxiety-related question | Emotional symptom             | Important ho sakta hai, but preprocessing me check karna padega ki duplicate hai ya alag wording effect hai |
# | 8  | **Have you been getting headaches more often than usual?**               | Frequent headaches                                   | Physical symptom              | Stress ka common somatic symptom; useful predictor                                                          |
# | 9  | **Do you get irritated easily?**                                         | Irritability / frustration level                     | Behavioral symptom            | Emotional instability aur stress overload ka indicator                                                      |
# | 10 | **Do you have trouble concentrating on your academic tasks?**            | Academic focus/concentration issues                  | Cognitive + academic symptom  | Stress academic productivity ko directly impact karta hai, isliye useful                                    |
# | 11 | **Have you been feeling sadness or low mood?**                           | Low mood / sadness                                   | Emotional symptom             | Stress aur depressive mood ke beech relation hota hai                                                       |
# | 12 | **Have you been experiencing any illness or health issues?**             | General health problems                              | Physical wellbeing            | Health issues stress ko increase kar sakte hain ya stress ka effect ho sakte hain                           |
# | 13 | **Do you often feel lonely or isolated?**                                | Loneliness / social isolation                        | Social-emotional factor       | Social isolation stress vulnerability ko badha sakta hai                                                    |
# | 14 | **Do you feel overwhelmed with your academic workload?**                 | Academic overload                                    | Academic pressure             | **Highly important** — student stress ka major driver                                                       |
# | 15 | **Are you in competition with your peers, and does it affect you?**      | Peer competition pressure                            | Social-academic pressure      | Comparison aur competition stress ko increase kar sakte hain                                                |
# | 16 | **Do you find that your relationship often causes you stress?**          | Relationship-based stress                            | Personal/social factor        | Emotional stressors ka strong source ho sakta hai                                                           |
# | 17 | **Are you facing any difficulties with your professors or instructors?** | Faculty-related issues                               | Academic environment          | Teacher/instructor issues academic stress ko amplify kar sakte hain                                         |
# | 18 | **Is your working environment unpleasant or stressful?**                 | Study/work environment stress                        | Environmental factor          | Surroundings and work environment stress level ko influence karte hain                                      |
# | 19 | **Do you struggle to find time for relaxation and leisure activities?**  | Lack of relaxation / no break time                   | Lifestyle balance             | Work-life imbalance aur burnout tendency ka indicator                                                       |
# | 20 | **Is your hostel or home environment causing you difficulties?**         | Home/hostel problems                                 | Environmental/social factor   | Living environment student mental health ko directly affect karta hai                                       |
# | 21 | **Do you lack confidence in your academic performance?**                 | Academic self-confidence issue                       | Self-esteem / academic factor | Low confidence often higher stress aur self-doubt se linked hoti hai                                        |
# | 22 | **Do you lack confidence in your choice of academic subjects?**          | Subject choice insecurity                            | Academic decision stress      | Career/subject uncertainty stress ka source ho sakti hai                                                    |
# | 23 | **Academic and extracurricular activities conflicting for you?**         | Time conflict between studies & activities           | Time-management / overload    | Overcommitment aur schedule conflict stress ko badhate hain                                                 |
# | 24 | **Do you attend classes regularly?**                                     | Class attendance behavior                            | Academic behavior             | Irregular attendance indirectly stress, burnout, or disengagement indicate kar sakti hai                    |
# | 25 | **Have you gained/lost weight?**                                         | Weight change                                        | Physical/health symptom       | Stress eating, poor appetite, or health issues ka indirect sign ho sakta hai                                |
# | 26 | **Which type of stress do you primarily experience?**                    | Primary stress category / target label               | **Target**                    | Model isi ko predict karega                                                                                 |
