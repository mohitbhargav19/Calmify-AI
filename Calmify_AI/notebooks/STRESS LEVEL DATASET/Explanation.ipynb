# %% [markdown]
# # <b><i><u>Stress Level Dataset ----</b></i></u>

# %% [markdown]
# <b><i>ALL THE FEATURES OF <U>Stress Level Dataset</U> ARE AS FOLLOWS --</B></U>

# %% [markdown]
# | Feature                      | Meaning                        | Importance           |
# | ---------------------------- | ------------------------------ | -------------------- |
# | anxiety_level                | Anxiety level of student       | ⭐⭐⭐⭐⭐ Very Important |
# | self_esteem                  | Confidence / self-worth        | ⭐⭐⭐⭐⭐ Very Important |
# | mental_health_history        | Past mental health issues      | ⭐⭐⭐⭐                 |
# | depression                   | Depression score               | ⭐⭐⭐⭐⭐                |
# | headache                     | Stress-related headaches       | ⭐⭐⭐                  |
# | blood_pressure               | BP level                       | ⭐⭐                   |
# | sleep_quality                | Quality of sleep               | ⭐⭐⭐⭐⭐                |
# | breathing_problem            | Breathing issues due to stress | ⭐⭐⭐                  |
# | noise_level                  | Environmental disturbance      | ⭐⭐⭐                  |
# | living_conditions            | Living environment quality     | ⭐⭐⭐                  |
# | safety                       | Feeling of safety              | ⭐⭐⭐                  |
# | basic_needs                  | Food, shelter, necessities     | ⭐⭐⭐                  |
# | academic_performance         | Academic results               | ⭐⭐⭐⭐                 |
# | study_load                   | Study burden                   | ⭐⭐⭐⭐⭐                |
# | teacher_student_relationship | Teacher support                | ⭐⭐⭐                  |
# | future_career_concerns       | Career anxiety                 | ⭐⭐⭐⭐                 |
# | social_support               | Friends/family support         | ⭐⭐⭐⭐⭐                |
# | peer_pressure                | Pressure from peers            | ⭐⭐⭐⭐                 |
# | extracurricular_activities   | Activities outside academics   | ⭐⭐                   |
# | bullying                     | Bullying exposure              | ⭐⭐⭐⭐                 |
# | stress_level                 | Target Variable                | 🎯                   |
