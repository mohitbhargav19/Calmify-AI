# %% [markdown]
# # <b><u><i>student_mental_health_burnout_1M </u> ----</b></i>

# %% [markdown]
# <b><i>ALL THE FEATURE OF <U>student_mental_health_burnout_1M</U> ARE AS FOLLOWS --

# %% [markdown]
# | Feature                  | Meaning                       | Importance for Burnout                                               |
# | ------------------------ | ----------------------------- | -------------------------------------------------------------------- |
# | **age**                  | Student ki age                | Different age groups burnout ko alag tarike se experience karte hain |
# | **gender**               | Male/Female                   | Burnout patterns gender ke hisab se vary kar sakte hain              |
# | **academic_year**        | 1st, 2nd, 3rd, 4th year       | Senior students par workload aur placement pressure zyada hota hai   |
# | **study_hours_per_day**  | Daily study time              | Excessive study burnout ka major cause ho sakta hai                  |
# | **exam_pressure**        | Exams ka stress level         | Burnout ke strongest predictors me se ek                             |
# | **academic_performance** | Academic score/performance    | Low performance frustration aur burnout badha sakta hai              |
# | **stress_level**         | Overall stress score          | Burnout ka direct precursor                                          |
# | **anxiety_score**        | Anxiety intensity             | High anxiety burnout risk ko increase karti hai                      |
# | **depression_score**     | Depression symptoms           | Emotional exhaustion ka major indicator                              |
# | **sleep_hours**          | Daily sleep duration          | Poor sleep burnout ka strongest factor hai                           |
# | **physical_activity**    | Exercise level                | Physical activity burnout ko reduce karti hai                        |
# | **social_support**       | Friends/family support        | Strong support system burnout ko prevent karta hai                   |
# | **screen_time**          | Daily screen exposure         | Excessive screen time fatigue aur stress badha sakta hai             |
# | **internet_usage**       | Internet usage hours          | Digital overload burnout me contribute kar sakta hai                 |
# | **financial_stress**     | Financial pressure            | Economic concerns mental exhaustion badhate hain                     |
# | **family_expectation**   | Family pressure               | High expectations burnout trigger kar sakti hain                     |
# | **burnout_score**        | Target Variable               | Model isi ko predict karega                                          |
# | **mental_health_index**  | Overall mental wellness score | Mental condition ka combined indicator                               |
# | **risk_level**           | Low / Medium / High Risk      | Burnout related derived category                                     |
# | **dropout_risk**         | Course chhodne ka risk        | Severe burnout ke cases me strongly related                          |
