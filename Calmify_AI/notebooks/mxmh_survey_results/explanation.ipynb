# %% [markdown]
# # <b><i><u>mxmh_survey_results</u> ----</b></i>

# %% [markdown]
# <B><I>ALL FEATURES OF DATASET <U>mxmh_survey_results</U> ARE AS FOLLOWS --></B></I>

# %% [markdown]
# | Column                        |                 Type | Short Explanation                                          | Calmify AI me Importance                                                                         |
# | ----------------------------- | -------------------: | ---------------------------------------------------------- | ------------------------------------------------------------------------------------------------ |
# | **Timestamp**                 |               Object | Response submit karne ka date-time                         | **Low** – model ke liye direct useful nahi; mostly survey metadata                               |
# | **Age**                       |              Numeric | User ki age                                                | **Medium** – age ke hisaab se music habits aur mental health pattern differ kar sakte hain       |
# | **Primary streaming service** |          Categorical | User ka main music platform (Spotify, YouTube Music, etc.) | **Low–Medium** – direct mental health predictor nahi, but listening ecosystem samajhne me useful |
# | **Hours per day**             |              Numeric | User kitne ghante per day music sunta hai                  | **High** – excessive ya healthy listening pattern detect karne me important                      |
# | **While working**             | Categorical (Yes/No) | Kya user kaam/study karte waqt music sunta hai             | **Medium** – focus, productivity, coping style aur study behavior se link ho sakta hai           |
# | **Instrumentalist**           |          Categorical | Kya user instrument bajata hai                             | **Medium** – active musical engagement emotional regulation se linked ho sakta hai               |
# | **Composer**                  |          Categorical | Kya user khud music compose karta hai                      | **Medium** – creativity, emotional expression aur music involvement ko show karta hai            |
# | **Fav genre**                 |          Categorical | User ka favourite music genre                              | **Very High** – Calmify AI ke music recommendation engine ka core feature                        |
# | **Exploratory**               |          Categorical | Kya user naye genres explore karta hai                     | **Medium** – recommendation personalization aur openness to new music ke liye useful             |
# | **Foreign languages**         |          Categorical | Kya user foreign language music sunta hai                  | **Low–Medium** – taste diversity aur openness ka indicator                                       |
# | **BPM**                       |              Numeric | Preferred/associated beats per minute of music             | **High** – calm, focus, sleep, energizing music recommendation me useful                         |
# | **Frequency [Classical]**     |  Ordinal categorical | User Classical kitni frequency se sunta hai                | **High** – genre-level listening preference aur mental-state relation ke liye useful             |
# | **Frequency [Country]**       |  Ordinal categorical | Country genre listening frequency                          | **Medium** – genre consumption pattern                                                           |
# | **Frequency [EDM]**           |  Ordinal categorical | EDM listening frequency                                    | **High** – stimulation / mood / energy relation samajhne ke liye useful                          |
# | **Frequency [Folk]**          |  Ordinal categorical | Folk listening frequency                                   | **Medium** – genre profile building                                                              |
# | **Frequency [Gospel]**        |  Ordinal categorical | Gospel listening frequency                                 | **Medium** – soothing/spiritual music pattern detect karne me useful                             |
# | **Frequency [Hip hop]**       |  Ordinal categorical | Hip hop listening frequency                                | **High** – energetic / expressive music preference mapping                                       |
# | **Frequency [Jazz]**          |  Ordinal categorical | Jazz listening frequency                                   | **Medium–High** – calm/focus/reflective listening behavior se link ho sakta hai                  |
# | **Frequency [K pop]**         |  Ordinal categorical | K-pop listening frequency                                  | **Medium** – genre behavior                                                                      |
