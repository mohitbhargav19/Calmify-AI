# %% [markdown]
# # <b><i><u>STUDENT MENTAL HEALTH SURVEY </U>----</B></I>

# %%
# FOR PATH RECOGNISION ----

from pathlib import Path

print("Current Folder:")
print(Path.cwd())

print("\nParent:")
print(Path.cwd().parent)
# Out:
# Current Folder:
# c:\Users\mohit\OneDrive\Desktop\Calmify AI\Calmify_AI\Calmify_AI\notebooks\students_mental_health_survey
#
# Parent:
# c:\Users\mohit\OneDrive\Desktop\Calmify AI\Calmify_AI\Calmify_AI\notebooks

# %%
# IGNORE WARNING --

import warnings

warnings.filterwarnings("ignore")

# %%
# IMPORTING ALL THE NECESSARY LIBRARIES --

# Data Handling

import pandas as pd
import numpy as np

# Visualization

import matplotlib.pyplot as plt
import seaborn as sns

# Preprocessing

from sklearn.preprocessing import (
    LabelEncoder,
    StandardScaler,
    MinMaxScaler
)

# Train Test Split

from sklearn.model_selection import (
    train_test_split,
    GridSearchCV,
    cross_val_score
)

# Models

from sklearn.ensemble import (
    RandomForestClassifier,
    RandomForestRegressor
)

from xgboost import (
    XGBClassifier,
    XGBRegressor
)

# Evaluation

from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    classification_report,
    confusion_matrix,
    mean_absolute_error,
    mean_squared_error,
    r2_score
)

# Model Saving

import joblib

# Display

pd.set_option(
    "display.max_columns",
    None
)

from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

from xgboost import XGBClassifier

sns.set_style("whitegrid")

print("all the necessary libraries are imported sucessfully:")
print("🎉🎉🎉🎉")
# Out:
# all the necessary libraries are imported sucessfully:
# 🎉🎉🎉🎉

# %%
# PATH SETUP
# current notebook folder
CURRENT_DIR = Path.cwd()

# notebooks folder
NOTEBOOKS_DIR = CURRENT_DIR.parent

# project root
BASE_DIR = NOTEBOOKS_DIR.parent

# folders
PREPROCESSED_DIR = NOTEBOOKS_DIR / "preprocessed"
MODELS_DIR = NOTEBOOKS_DIR / "models"

PREPROCESSED_DIR.mkdir(parents=True, exist_ok=True)
MODELS_DIR.mkdir(parents=True, exist_ok=True)

# file path
DATA_PATH = PREPROCESSED_DIR / "students_mental_health_survey_model_ready.csv"

print("Current Dir:", CURRENT_DIR)
print("Notebooks Dir:", NOTEBOOKS_DIR)
print("Preprocessed Dir:", PREPROCESSED_DIR)
print("Models Dir:", MODELS_DIR)
print("Data Path:", DATA_PATH)
# Out:
# Current Dir: c:\Users\mohit\OneDrive\Desktop\Calmify AI\Calmify_AI\Calmify_AI\notebooks\students_mental_health_survey
# Notebooks Dir: c:\Users\mohit\OneDrive\Desktop\Calmify AI\Calmify_AI\Calmify_AI\notebooks
# Preprocessed Dir: c:\Users\mohit\OneDrive\Desktop\Calmify AI\Calmify_AI\Calmify_AI\notebooks\preprocessed
# Models Dir: c:\Users\mohit\OneDrive\Desktop\Calmify AI\Calmify_AI\Calmify_AI\notebooks\models
# Data Path: c:\Users\mohit\OneDrive\Desktop\Calmify AI\Calmify_AI\Calmify_AI\notebooks\preprocessed\students_mental_health_survey_model_ready.csv

# %%
# LOADING DATASET --

df = pd.read_csv(DATA_PATH)

print("Shape:", df.shape)
df.head()
# Out:
# Shape: (7022, 28)
#    age  gender  cgpa  stress_level  depression_score  anxiety_score  \
# 0   25       1  3.56             3                 3              2
# 1   24       0  2.44             0                 3              0
# 2   19       0  3.74             4                 0              3
# 3   19       1  3.65             2                 1              0
# 4   18       1  3.40             3                 3              4
#
#    sleep_quality  physical_activity  diet_quality  social_support  \
# 0              2                  1             2               1
# 1              1                  0             1               0
# 2              2                  0             1               1
# 3              1                  0             1               1
# 4              2                  0             1               2
#
#    relationship_status  substance_use  counseling_service_use  family_history  \
# 0                    2              0                       0               0
# 1                    0              1                       1               0
# 2                    1              0                       1               0
# 3                    0              0                       0               0
# 4                    2              0                       0               0
#
#    chronic_illness  financial_stress  extracurricular_involvement  \
# 0                0                 2                            1
# 1                0                 3                            0
# 2                0                 4                            2
# 3                0                 4                            1
# 4                1                 0                            2
#
#    semester_credit_load  residence_type  course_Computer Science  \
# 0                    17               0                    False
# 1                    27               0                    False
# 2                    15               0                    False
# 3                    20               1                     True
# 4                    23               0                    False
#
#    course_Engineering  course_Law  course_Medical  course_Others  cgpa_risk  \
# 0               False       False           False           True       0.44
# 1                True       False           False          False       1.56
# 2               False       False           False          False       0.26
# 3               False       False           False          False       0.35
# 4               False       False           False          False       0.60
#
#    health_risk_score  social_risk_score  overall_risk_score
# 0                  0                  4               13.14
# 1                  2                  4               16.26
# 2                  1                  2               11.76
# 3                  0                  2                9.35
# 4                  1                  2               12.90

# %%
# BASIC INSPECTION --

print("Columns:")
print(df.columns.tolist())

print("\nInfo:")
print(df.info())

print("\nTarget distribution:")
print(df["stress_level"].value_counts().sort_index())
# Out:
# Columns:
# ['age', 'gender', 'cgpa', 'stress_level', 'depression_score', 'anxiety_score', 'sleep_quality', 'physical_activity', 'diet_quality', 'social_support', 'relationship_status', 'substance_use', 'counseling_service_use', 'family_history', 'chronic_illness', 'financial_stress', 'extracurricular_involvement', 'semester_credit_load', 'residence_type', 'course_Computer Science', 'course_Engineering', 'course_Law', 'course_Medical', 'course_Others', 'cgpa_risk', 'health_risk_score', 'social_risk_score', 'overall_risk_score']
#
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7022 entries, 0 to 7021
# Data columns (total 28 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   age                          7022 non-null   int64
#  1   gender                       7022 non-null   int64
#  2   cgpa                         7022 non-null   float64
#  3   stress_level                 7022 non-null   int64
#  4   depression_score             7022 non-null   int64
#  5   anxiety_score                7022 non-null   int64
#  6   sleep_quality                7022 non-null   int64
#  7   physical_activity            7022 non-null   int64
#  8   diet_quality                 7022 non-null   int64
#  9   social_support               7022 non-null   int64
#  10  relationship_status          7022 non-null   int64
#  11  substance_use                7022 non-null   int64
#  12  counseling_service_use       7022 non-null   int64
#  13  family_history               7022 non-null   int64
#  14  chronic_illness              7022 non-null   int64
#  15  financial_stress             7022 non-null   int64
#  16  extracurricular_involvement  7022 non-null   int64
#  17  semester_credit_load         7022 non-null   int64
#  18  residence_type               7022 non-null   int64
#  19  course_Computer Science      7022 non-null   bool
#  20  course_Engineering           7022 non-null   bool
#  21  course_Law                   7022 non-null   bool
#  22  course_Medical               7022 non-null   bool
#  23  course_Others                7022 non-null   bool
#  24  cgpa_risk                    7022 non-null   float64
#  25  health_risk_score            7022 non-null   int64
#  26  social_risk_score            7022 non-null   int64
#  27  overall_risk_score           7022 non-null   float64
# dtypes: bool(5), float64(3), int64(20)
# memory usage: 1.3 MB
# None
#
# Target distribution:
# stress_level
# 0    1098
# 1    1233
# 2    1279
# 3    1405
# 4     992
# 5    1015
# Name: count, dtype: int64

# %%
# DEFINING X AND Y --

TARGET_COL = "stress_level"

X = df.drop(columns=[TARGET_COL])
y = df[TARGET_COL]

print("X shape:", X.shape)
print("y shape:", y.shape)
# Out:
# X shape: (7022, 27)
# y shape: (7022,)

# %%
# FEATURE NAME --

feature_names = X.columns.tolist()

print("Total features:", len(feature_names))
feature_names[:20]
# Out:
# Total features: 27
# ['age',
#  'gender',
#  'cgpa',
#  'depression_score',
#  'anxiety_score',
#  'sleep_quality',
#  'physical_activity',
#  'diet_quality',
#  'social_support',
#  'relationship_status',
#  'substance_use',
#  'counseling_service_use',
#  'family_history',
#  'chronic_illness',
#  'financial_stress',
#  'extracurricular_involvement',
#  'semester_credit_load',
#  'residence_type',
#  'course_Computer Science',
#  'course_Engineering']

# %%
# TRAIN TEST SPLIT --

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

print("X_train:", X_train.shape)
print("X_test :", X_test.shape)
print("y_train:", y_train.shape)
print("y_test :", y_test.shape)
# Out:
# X_train: (5617, 27)
# X_test : (1405, 27)
# y_train: (5617,)
# y_test : (1405,)

# %% [markdown]
# # <B><U><I>MODEL 1 </U>----

# %%
# LOGGISTIC REGRESSION --

log_reg_pipeline = Pipeline([
    ("scaler", StandardScaler()),
    ("model", LogisticRegression(
        max_iter=3000,
        random_state=42
    ))
])

# %%
log_reg_pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('model', LogisticRegression(max_iter=3000, random_state=42))])

# %%
# EVALUATION --

y_pred_lr = log_reg_pipeline.predict(X_test)

lr_acc = accuracy_score(y_test, y_pred_lr)
lr_f1 = f1_score(y_test, y_pred_lr, average="weighted")

print("Logistic Regression Accuracy:", round(lr_acc * 100, 2), "%")
print("Logistic Regression Weighted F1:", round(lr_f1, 4))

print("\nClassification Report:\n")
print(classification_report(y_test, y_pred_lr))

print("\nConfusion Matrix:\n")
print(confusion_matrix(y_test, y_pred_lr))
# Out:
# Logistic Regression Accuracy: 21.99 %
# Logistic Regression Weighted F1: 0.2183
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.20      0.24      0.22       220
#            1       0.21      0.22      0.21       247
#            2       0.18      0.15      0.16       256
#            3       0.22      0.21      0.21       281
#            4       0.24      0.32      0.28       198
#            5       0.29      0.21      0.24       203
#
#     accuracy                           0.22      1405
#    macro avg       0.22      0.22      0.22      1405
# weighted avg       0.22      0.22      0.22      1405
#
#
# Confusion Matrix:
#
# [[52 46 45 57 16  4]
#  [50 54 49 50 29 15]
#  [57 56 38 49 36 20]
#  [40 49 41 59 62 30]
#  [33 24 15 25 63 38]
#  [26 28 22 30 54 43]]

# %% [markdown]
# # <B><I><U>MODEL 2</U> ----</B></I>

# %%
# RANDOM FOREST --

rf_model = RandomForestClassifier(
    n_estimators=300,
    max_depth=None,
    min_samples_split=5,
    min_samples_leaf=2,
    random_state=42,
    n_jobs=-1
)

# %%
rf_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(min_samples_leaf=2, min_samples_split=5,
#                        n_estimators=300, n_jobs=-1, random_state=42)

# %%
# EVALUATION --

y_pred_rf = rf_model.predict(X_test)

rf_acc = accuracy_score(y_test, y_pred_rf)
rf_f1 = f1_score(y_test, y_pred_rf, average="weighted")

print("Random Forest Accuracy:", round(rf_acc * 100, 2), "%")
print("Random Forest Weighted F1:", round(rf_f1, 4))

print("\nClassification Report:\n")
print(classification_report(y_test, y_pred_rf))

print("\nConfusion Matrix:\n")
print(confusion_matrix(y_test, y_pred_rf))
# Out:
# Random Forest Accuracy: 20.64 %
# Random Forest Weighted F1: 0.2052
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.24      0.25      0.24       220
#            1       0.20      0.24      0.22       247
#            2       0.15      0.13      0.14       256
#            3       0.21      0.23      0.22       281
#            4       0.22      0.21      0.21       198
#            5       0.24      0.17      0.20       203
#
#     accuracy                           0.21      1405
#    macro avg       0.21      0.21      0.21      1405
# weighted avg       0.21      0.21      0.21      1405
#
#
# Confusion Matrix:
#
# [[55 53 47 47 11  7]
#  [37 60 52 61 23 14]
#  [51 67 34 57 28 19]
#  [40 53 47 64 43 34]
#  [28 31 20 38 42 39]
#  [21 29 33 39 46 35]]

# %% [markdown]
# # <B><U><I>MODEL 3</U> ----</B></I>

# %%
# XG_BOOST --

xgb_model = XGBClassifier(
    n_estimators=300,
    max_depth=6,
    learning_rate=0.05,
    subsample=0.9,
    colsample_bytree=0.9,
    objective="multi:softmax",
    num_class=len(np.unique(y)),
    random_state=42,
    eval_metric="mlogloss"
)

# %%
xgb_model.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.9, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='mlogloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.05, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=6, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=300, n_jobs=None, num_class=6, ...)

# %%
# EVALUATION --

y_pred_xgb = xgb_model.predict(X_test)

xgb_acc = accuracy_score(y_test, y_pred_xgb)
xgb_f1 = f1_score(y_test, y_pred_xgb, average="weighted")

print("XGBoost Accuracy:", round(xgb_acc * 100, 2), "%")
print("XGBoost Weighted F1:", round(xgb_f1, 4))

print("\nClassification Report:\n")
print(classification_report(y_test, y_pred_xgb))

print("\nConfusion Matrix:\n")
print(confusion_matrix(y_test, y_pred_xgb))
# Out:
# XGBoost Accuracy: 20.07 %
# XGBoost Weighted F1: 0.1999
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.21      0.24      0.22       220
#            1       0.20      0.23      0.21       247
#            2       0.16      0.16      0.16       256
#            3       0.21      0.22      0.22       281
#            4       0.20      0.17      0.19       198
#            5       0.23      0.17      0.20       203
#
#     accuracy                           0.20      1405
#    macro avg       0.20      0.20      0.20      1405
# weighted avg       0.20      0.20      0.20      1405
#
#
# Confusion Matrix:
#
# [[53 58 45 43 11 10]
#  [49 56 49 49 26 18]
#  [51 66 42 57 23 17]
#  [46 50 54 63 35 33]
#  [32 32 26 41 34 33]
#  [24 25 39 44 37 34]]

# %%
# MODEL COMPARISON --

results = pd.DataFrame({
    "Model": [
        "Logistic Regression",
        "Random Forest",
        "XGBoost"
    ],
    "Accuracy": [
        lr_acc,
        rf_acc,
        xgb_acc
    ],
    "Weighted_F1": [
        lr_f1,
        rf_f1,
        xgb_f1
    ]
})

results = results.sort_values(by=["Accuracy", "Weighted_F1"], ascending=False).reset_index(drop=True)
results
# Out:
#                  Model  Accuracy  Weighted_F1
# 0  Logistic Regression  0.219929     0.218257
# 1        Random Forest  0.206406     0.205213
# 2              XGBoost  0.200712     0.199924

# %%
model_save_path = MODELS_DIR / "student_survey_stress_model.pkl"

joblib.dump(log_reg_pipeline, model_save_path)

print("Best model saved successfully")
print("Saved at:", model_save_path)
# Out:
# Best model saved successfully
# Saved at: c:\Users\mohit\OneDrive\Desktop\Calmify AI\Calmify_AI\Calmify_AI\notebooks\models\student_survey_stress_model.pkl

# %%
print(type(log_reg_pipeline))

print(log_reg_pipeline)

print(hasattr(log_reg_pipeline, "predict_proba"))
# Out:
# <class 'sklearn.pipeline.Pipeline'>
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('model', LogisticRegression(max_iter=3000, random_state=42))])
# True

# %%
pred = log_reg_pipeline.predict(X_test)

print(pred[:10])
print(pred.min())
print(pred.max())
# Out:
# [3 4 2 3 1 4 4 4 0 1]
# 0
# 5

# %%
print(df[y].head())

print(df[y].dtype)

print(df[y].value_counts().head(20))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 print(df[y].head())
#       3 print(df[y].dtype)
#       5 print(df[y].value_counts().head(20))
#
# File c:\Users\mohit\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Users\mohit\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File c:\Users\mohit\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:6249, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6247 if nmissing:
#    6248     if nmissing == len(indexer):
# -> 6249         raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251     not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6252     raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index([3, 0, 4, 2, 3, 2, 2, 0, 3, 2,\n       ...\n       1, 0, 0, 5, 1, 3, 3, 4, 4, 3],\n      dtype='int64', length=7022)] are in the [columns]"
