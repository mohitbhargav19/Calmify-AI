# %% [markdown]
# # <b><i><u>students_mental_health_survey </u>----</b><i>

# %% [markdown]
# <b><i>ALL THE FEATURES OF <u>students_mental_health_survey</U> ARE AS FOLLOWS -->

# %% [markdown]
# | Feature                         |             Type | Meaning                                                           | Why it matters for mental health / stress                                                                                           | Expected Importance |
# | ------------------------------- | ---------------: | ----------------------------------------------------------------- | ----------------------------------------------------------------------------------------------------------------------------------- | ------------------: |
# | **Age**                         |          Numeric | Student ki age                                                    | Different age groups ka academic pressure, maturity, coping pattern aur life responsibilities alag ho sakte hain                    |              Medium |
# | **Course**                      |      Categorical | Student ka field/discipline (Engineering, Medical, Business etc.) | Different courses ka workload, competition aur exam pattern stress ko affect kar sakta hai                                          |              Medium |
# | **Gender**                      |      Categorical | Male/Female                                                       | Stress reporting, help-seeking behavior, emotional expression me differences ho sakte hain                                          |              Medium |
# | **CGPA**                        |          Numeric | Academic performance / grade point average                        | Low CGPA academic pressure aur self-esteem issues se linked ho sakta hai; high CGPA bhi performance pressure la sakta hai           |                High |
# | **Stress_Level**                | Numeric (Target) | Student ka stress outcome level                                   | Ye wahi variable hai jise hum predict karenge                                                                                       |          **Target** |
# | **Depression_Score**            |          Numeric | Depression symptoms ka score                                      | Depression aur stress often strongly related hote hain; low motivation, hopelessness, fatigue etc. stress ko reflect kar sakte hain |            **High** |
# | **Anxiety_Score**               |          Numeric | Anxiety symptoms ka score                                         | Anxiety usually stress ka strong psychological indicator hota hai                                                                   |            **High** |
# | **Sleep_Quality**               |      Categorical | Sleep quality (Good/Average/Poor)                                 | Poor sleep mental health, emotional regulation, concentration aur stress tolerance ko directly affect karti hai                     |            **High** |
# | **Physical_Activity**           |      Categorical | Activity level (Low/Moderate/High)                                | Exercise stress reduce karne me helpful hoti hai; low activity higher stress se linked ho sakti hai                                 |         Medium–High |
# | **Diet_Quality**                |      Categorical | Food / nutrition quality                                          | Poor diet energy, mood, sleep aur concentration ko affect kar sakti hai                                                             |              Medium |
# | **Social_Support**              |      Categorical | Friends/family/peers ka support level                             | Strong support usually stress ko buffer karta hai                                                                                   |            **High** |
# | **Relationship_Status**         |      Categorical | Single / Married / In relationship                                | Relationship stability ya conflict emotional stress ko impact kar sakta hai                                                         |              Medium |
# | **Substance_Use**               |      Categorical | Smoking/alcohol etc. use frequency                                | Coping mechanism ya risk behavior ka signal ho sakta hai; stress/burnout se linked ho sakta hai                                     |         Medium–High |
# | **Counseling_Service_Use**      |      Categorical | Counseling use ki frequency                                       | Help-seeking behavior aur underlying mental health concern ka indirect indicator ho sakta hai                                       |              Medium |
# | **Family_History**              |      Categorical | Family history of mental health issues                            | Vulnerability / predisposition ka signal ho sakta hai                                                                               |              Medium |
# | **Chronic_Illness**             |      Categorical | Chronic medical illness present hai ya nahi                       | Long-term illness stress, fatigue, emotional burden aur routine difficulty badha sakti hai                                          |              Medium |
# | **Financial_Stress**            |          Numeric | Money-related stress level                                        | Student mental health me financial pressure ek major risk factor hota hai                                                           |            **High** |
# | **Extracurricular_Involvement** |      Categorical | Activities/clubs/sports involvement                               | Balanced involvement stress reduce kar sakta hai; over-involvement ya no involvement dono informative ho sakte hain                 |              Medium |
# | **Semester_Credit_Load**        |          Numeric | Semester me liye गए credits / workload                            | Direct academic load ka measure hai; zyada credits = zyada pressure ka possibility                                                  |            **High** |
# | **Residence_Type**              |      Categorical | On-campus / Off-campus / etc.                                     | Living environment, commute, support system aur comfort stress ko influence kar sakte hain                                          |              Medium |
